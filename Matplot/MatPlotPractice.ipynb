# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot(5,5,'o')
plt.ylabel('bottom')
plt.xlabel('left')
plt.title('top')
# Out:
# Text(0.5, 1.0, 'top')

# %%
sql_query = "SELECT * FROM my_table WHERE column_name > 10"
df = pd.read_sql(sql_query, engine)

    print(df.head())
# Out:
#   Cell In[9], line 4
#     print(df.head())
#     ^
# IndentationError: unexpected indent
